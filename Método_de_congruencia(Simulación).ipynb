# %% [markdown]
# <a href="https://colab.research.google.com/github/alexloaeza12/Simulaci-n-I/blob/main/M%C3%A9todo_de_congruencia(Simulaci%C3%B3n).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tabulate import tabulate

print("******************************************")
print("* Programa del Método de Congruencia *")
print("******************************************\n")

# Solicitamos al usuario el primer número de 3 dígitos
num_alta = int(input("Ingresa un número el cúal será tu constante 'a': "))
num_altc = int(input("Ingresa un número el cúal será tu constante 'c': "))
num_altm = int(input("Ingresa un número el cúal será tu constante 'm': "))

while True:
    num_altxn = int(input("Ingresa un número el cúal será tu semilla 'x_n': "))
    if 0 < num_altxn < num_altm:
        break
    else:
        print("Por favor, ingresa una semilla válida. Debe ser mayor a '0' y menor a 'm'.")

# Solicitamos al usuario la cantidad de iteraciones
num_iteraciones = int(input("Ingresa la cantidad de iteraciones que deseas realizar: "))

# Almacenamos los resultados en una lista
resultados = []

# Construimos los datos para la tabla
for i in range(num_iteraciones):
    num_alt2 = num_altxn * num_alta + num_altc
    num_alt3 = num_alt2 % num_altm
    num_alt4 = num_altxn / num_altm

    # Almacenar los resultados en la lista
    resultados.append((i, num_altxn, num_alt2, num_alt3, num_alt4))

    # Establecemos el nuevo valor de num_altxn para la siguiente iteración
    num_altxn = num_alt3

# Imprimimos la tabla
headers = ["Iteración", "Semilla", "Producto", "Sobrante", "Resultado"]
print(tabulate(resultados, headers=headers, tablefmt="grid"))
# Out:
# ******************************************
# * Programa del Método de la congruenciao *
# ******************************************
#
# Ingresa un número el cúal será tu constante 'a': 5
# Ingresa un número el cúal será tu constante 'c': 5
# Ingresa un número el cúal será tu constante 'm': 16
# Ingresa un número el cúal será tu semilla 'x_n': 6
# Ingresa la cantidad de iteraciones que deseas realizar: 100
# +-------------+-----------+------------+------------+-------------+
# |   Iteración |   Semilla |   Producto |   Sobrante |   Resultado |
# +=============+===========+============+============+=============+
# |           0 |         6 |         35 |          3 |      0.375  |
# +-------------+-----------+------------+------------+-------------+
# |           1 |         3 |         20 |          4 |      0.1875 |
# +-------------+-----------+------------+------------+-------------+
# |           2 |         4 |         25 |          9 |      0.25   |
# +-------------+-----------+------------+------------+-------------+
# |           3 |         9 |         50 |          2 |      0.5625 |
# +-------------+-----------+------------+------------+-------------+
# |           4 |         2 |         15 |         15 |      0.125  |
# +-------------+-----------+------------+------------+-------------+
# |           5 |        15 |         80 |          0 |      0.9375 |
# +-------------+-----------+------------+------------+-------------+
# |           6 |         0 |          5 |          5 |      0      |
# +-------------+-----------+------------+------------+-------------+
# |           7 |         5 |         30 |         14 |      0.3125 |
# +-------------+-----------+------------+------------+-------------+
# |           8 |        14 |         75 |         11 |      0.875  |
# +-------------+-----------+------------+------------+-------------+
# |           9 |        11 |         60 |         12 |      0.6875 |
# +-------------+-----------+------------+------------+-------------+
# |          10 |        12 |         65 |          1 |      0.75   |
# +-------------+-----------+------------+------------+-------------+
# |          11 |         1 |         10 |         10 |      0.0625 |
# +-------------+-----------+------------+------------+-------------+
# |          12 |        10 |         55 |          7 |      0.625  |
# +-------------+-----------+------------+------------+-------------+
# |          13 |         7 |         40 |          8 |      0.4375 |
# +-------------+-----------+------------+------------+-------------+
# |          14 |         8 |         45 |         13 |      0.5    |
# +-------------+-----------+------------+------------+-------------+
# |          15 |        13 |         70 |          6 |      0.8125 |
# +-------------+-----------+------------+------------+-------------+
# |          16 |         6 |         35 |          3 |      0.375  |
# +-------------+-----------+------------+------------+-------------+
# |          17 |         3 |         20 |          4 |      0.1875 |
# +-------------+-----------+------------+------------+-------------+
# |          18 |         4 |         25 |          9 |      0.25   |
# +-------------+-----------+------------+------------+-------------+
# |          19 |         9 |         50 |          2 |      0.5625 |
# +-------------+-----------+------------+------------+-------------+
# |          20 |         2 |         15 |         15 |      0.125  |
# +-------------+-----------+------------+------------+-------------+
# |          21 |        15 |         80 |          0 |      0.9375 |
# +-------------+-----------+------------+------------+-------------+
# |          22 |         0 |          5 |          5 |      0      |
# +-------------+-----------+------------+------------+-------------+
# |          23 |         5 |         30 |         14 |      0.3125 |
# +-------------+-----------+------------+------------+-------------+
# |          24 |        14 |         75 |         11 |      0.875  |
# +-------------+-----------+------------+------------+-------------+
# |          25 |        11 |         60 |         12 |      0.6875 |
# +-------------+-----------+------------+------------+-------------+
# |          26 |        12 |         65 |          1 |      0.75   |
# +-------------+-----------+------------+------------+-------------+
# |          27 |         1 |         10 |         10 |      0.0625 |
# +-------------+-----------+------------+------------+-------------+
# |          28 |        10 |         55 |          7 |      0.625  |
# +-------------+-----------+------------+------------+-------------+
# |          29 |         7 |         40 |          8 |      0.4375 |
# +-------------+-----------+------------+------------+-------------+
# |          30 |         8 |         45 |         13 |      0.5    |
# +-------------+-----------+------------+------------+-------------+
# |          31 |        13 |         70 |          6 |      0.8125 |
# +-------------+-----------+------------+------------+-------------+
# |          32 |         6 |         35 |          3 |      0.375  |
# +-------------+-----------+------------+------------+-------------+
# |          33 |         3 |         20 |          4 |      0.1875 |
# +-------------+-----------+------------+------------+-------------+
# |          34 |         4 |         25 |          9 |      0.25   |
# +-------------+-----------+------------+------------+-------------+
# |          35 |         9 |         50 |          2 |      0.5625 |
# +-------------+-----------+------------+------------+-------------+
# |          36 |         2 |         15 |         15 |      0.125  |
# +-------------+-----------+------------+------------+-------------+
# |          37 |        15 |         80 |          0 |      0.9375 |
# +-------------+-----------+------------+------------+-------------+
# |          38 |         0 |          5 |          5 |      0      |
# +-------------+-----------+------------+------------+-------------+
# |          39 |         5 |         30 |         14 |      0.3125 |
# +-------------+-----------+------------+------------+-------------+
# |          40 |        14 |         75 |         11 |      0.875  |
# +-------------+-----------+------------+------------+-------------+
# |          41 |        11 |         60 |         12 |      0.6875 |
# +-------------+-----------+------------+------------+-------------+
# |          42 |        12 |         65 |          1 |      0.75   |
# +-------------+-----------+------------+------------+-------------+
# |          43 |         1 |         10 |         10 |      0.0625 |
# +-------------+-----------+------------+------------+-------------+
# |          44 |        10 |         55 |          7 |      0.625  |
# +-------------+-----------+------------+------------+-------------+
# |          45 |         7 |         40 |          8 |      0.4375 |
# +-------------+-----------+------------+------------+-------------+
# |          46 |         8 |         45 |         13 |      0.5    |
# +-------------+-----------+------------+------------+-------------+
# |          47 |        13 |         70 |          6 |      0.8125 |
# +-------------+-----------+------------+------------+-------------+
# |          48 |         6 |         35 |          3 |      0.375  |
# +-------------+-----------+------------+------------+-------------+
# |          49 |         3 |         20 |          4 |      0.1875 |
# +-------------+-----------+------------+------------+-------------+
# |          50 |         4 |         25 |          9 |      0.25   |
# +-------------+-----------+------------+------------+-------------+
# |          51 |         9 |         50 |          2 |      0.5625 |
# +-------------+-----------+------------+------------+-------------+
# |          52 |         2 |         15 |         15 |      0.125  |
# +-------------+-----------+------------+------------+-------------+
# |          53 |        15 |         80 |          0 |      0.9375 |
# +-------------+-----------+------------+------------+-------------+
# |          54 |         0 |          5 |          5 |      0      |
# +-------------+-----------+------------+------------+-------------+
# |          55 |         5 |         30 |         14 |      0.3125 |
# +-------------+-----------+------------+------------+-------------+
# |          56 |        14 |         75 |         11 |      0.875  |
# +-------------+-----------+------------+------------+-------------+
# |          57 |        11 |         60 |         12 |      0.6875 |
# +-------------+-----------+------------+------------+-------------+
# |          58 |        12 |         65 |          1 |      0.75   |
# +-------------+-----------+------------+------------+-------------+
# |          59 |         1 |         10 |         10 |      0.0625 |
# +-------------+-----------+------------+------------+-------------+
# |          60 |        10 |         55 |          7 |      0.625  |
# +-------------+-----------+------------+------------+-------------+
# |          61 |         7 |         40 |          8 |      0.4375 |
# +-------------+-----------+------------+------------+-------------+
# |          62 |         8 |         45 |         13 |      0.5    |
# +-------------+-----------+------------+------------+-------------+
# |          63 |        13 |         70 |          6 |      0.8125 |
# +-------------+-----------+------------+------------+-------------+
# |          64 |         6 |         35 |          3 |      0.375  |
# +-------------+-----------+------------+------------+-------------+
# |          65 |         3 |         20 |          4 |      0.1875 |
# +-------------+-----------+------------+------------+-------------+
# |          66 |         4 |         25 |          9 |      0.25   |
# +-------------+-----------+------------+------------+-------------+
# |          67 |         9 |         50 |          2 |      0.5625 |
# +-------------+-----------+------------+------------+-------------+
# |          68 |         2 |         15 |         15 |      0.125  |
# +-------------+-----------+------------+------------+-------------+
# |          69 |        15 |         80 |          0 |      0.9375 |
# +-------------+-----------+------------+------------+-------------+
# |          70 |         0 |          5 |          5 |      0      |
# +-------------+-----------+------------+------------+-------------+
# |          71 |         5 |         30 |         14 |      0.3125 |
# +-------------+-----------+------------+------------+-------------+
# |          72 |        14 |         75 |         11 |      0.875  |
# +-------------+-----------+------------+------------+-------------+
# |          73 |        11 |         60 |         12 |      0.6875 |
# +-------------+-----------+------------+------------+-------------+
# |          74 |        12 |         65 |          1 |      0.75   |
# +-------------+-----------+------------+------------+-------------+
# |          75 |         1 |         10 |         10 |      0.0625 |
# +-------------+-----------+------------+------------+-------------+
# |          76 |        10 |         55 |          7 |      0.625  |
# +-------------+-----------+------------+------------+-------------+
# |          77 |         7 |         40 |          8 |      0.4375 |
# +-------------+-----------+------------+------------+-------------+
# |          78 |         8 |         45 |         13 |      0.5    |
# +-------------+-----------+------------+------------+-------------+
# |          79 |        13 |         70 |          6 |      0.8125 |
# +-------------+-----------+------------+------------+-------------+
# |          80 |         6 |         35 |          3 |      0.375  |
# +-------------+-----------+------------+------------+-------------+
# |          81 |         3 |         20 |          4 |      0.1875 |
# +-------------+-----------+------------+------------+-------------+
# |          82 |         4 |         25 |          9 |      0.25   |
# +-------------+-----------+------------+------------+-------------+
# |          83 |         9 |         50 |          2 |      0.5625 |
# +-------------+-----------+------------+------------+-------------+
# |          84 |         2 |         15 |         15 |      0.125  |
# +-------------+-----------+------------+------------+-------------+
# |          85 |        15 |         80 |          0 |      0.9375 |
# +-------------+-----------+------------+------------+-------------+
# |          86 |         0 |          5 |          5 |      0      |
# +-------------+-----------+------------+------------+-------------+
# |          87 |         5 |         30 |         14 |      0.3125 |
# +-------------+-----------+------------+------------+-------------+
# |          88 |        14 |         75 |         11 |      0.875  |
# +-------------+-----------+------------+------------+-------------+
# |          89 |        11 |         60 |         12 |      0.6875 |
# +-------------+-----------+------------+------------+-------------+
# |          90 |        12 |         65 |          1 |      0.75   |
# +-------------+-----------+------------+------------+-------------+
# |          91 |         1 |         10 |         10 |      0.0625 |
# +-------------+-----------+------------+------------+-------------+
# |          92 |        10 |         55 |          7 |      0.625  |
# +-------------+-----------+------------+------------+-------------+
# |          93 |         7 |         40 |          8 |      0.4375 |
# +-------------+-----------+------------+------------+-------------+
# |          94 |         8 |         45 |         13 |      0.5    |
# +-------------+-----------+------------+------------+-------------+
# |          95 |        13 |         70 |          6 |      0.8125 |
# +-------------+-----------+------------+------------+-------------+
# |          96 |         6 |         35 |          3 |      0.375  |
# +-------------+-----------+------------+------------+-------------+
# |          97 |         3 |         20 |          4 |      0.1875 |
# +-------------+-----------+------------+------------+-------------+
# |          98 |         4 |         25 |          9 |      0.25   |
# +-------------+-----------+------------+------------+-------------+
# |          99 |         9 |         50 |          2 |      0.5625 |
# +-------------+-----------+------------+------------+-------------+
