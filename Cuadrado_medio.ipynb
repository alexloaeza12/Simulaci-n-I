# %% [markdown]
# <a href="https://colab.research.google.com/github/alexloaeza12/Simulaci-n-I/blob/main/Cuadrado_medio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tabulate import tabulate

print("********************************")
print("* Programa del Cuadrado Medio *")
print("********************************\n")

# Solicitamos al usuario un número de 4 dígitos
while True:
    num_alt = input("Ingresa un número de 4 dígitos: ")
    if num_alt.isdigit() and len(num_alt) == 4:
        num_alt = int(num_alt)
        break
    else:
        print("Por favor, ingresa un número válido de 4 dígitos.")

# Solicitmos al usuario la cantidad de iteraciones
num_iteraciones = int(input("Ingresa la cantidad de iteraciones que deseas realizar: "))

# Almacenamos los resultados en una lista
resultados = []

# Construimos los datos para la tabla
for i in range(num_iteraciones):
    num_alt2 = num_alt * num_alt

    # Convertimos el resultado a cadena y obtener la longitud
    result_str = str(num_alt2)
    result_length = len(result_str)

  #Por ejemplo:
  #Calculamos el cuadrado de "1234", que es "1522756".
  #Luego, calculamos la longitud de la cadena resultante, que es result_long = len("1522756"), por lo que result_long es 7.
  #Ahora, calculamos la posición inicial para los 4 dígitos del medio: ini_posicion = (7 - 4) // 2, que es igual a 1.
  #La posición final sería: fin_posicion = ini_posicion + 4, por lo que fin_posicion sería 5.
    # Calculamos la posición inicial y final para los 4 dígitos de en medio
    start_position = (result_length - 4) // 2
    end_position = start_position + 4

    # Extraer los 4 dígitos de en medio
    middle_four_digits = result_str[start_position:end_position]

    # Almacenar los resultados en la lista
    resultados.append((i+1, num_alt, num_alt2, middle_four_digits))

    # Establecer el nuevo valor de num_alt para la siguiente iteración con la codición de agregar un "0" a los números con dígitos impares
    num_alt = int("0" + middle_four_digits) if result_length % 2 != 0 else int(middle_four_digits)

# Imprimir la tabla
headers = ["Iteración", "Cuadrado medio", "Cuadrado medio al cuadrado", "Cuadrado medio continuo"]
print(tabulate(resultados, headers=headers, tablefmt="grid"))
# Out:
# ********************************
# * Programa del Cuadrado Medio *
# ********************************
#
# Ingresa un número de 4 dígitos: 5632
# Ingresa la cantidad de iteraciones que deseas realizar: 65
# +-------------+------------------+------------------------------+---------------------------+
# |   Iteración |   Cuadrado medio |   Cuadrado medio al cuadrado |   Cuadrado medio continuo |
# +=============+==================+==============================+===========================+
# |           1 |             5632 |                     31719424 |                      7194 |
# +-------------+------------------+------------------------------+---------------------------+
# |           2 |             7194 |                     51753636 |                      7536 |
# +-------------+------------------+------------------------------+---------------------------+
# |           3 |             7536 |                     56791296 |                      7912 |
# +-------------+------------------+------------------------------+---------------------------+
# |           4 |             7912 |                     62599744 |                      5997 |
# +-------------+------------------+------------------------------+---------------------------+
# |           5 |             5997 |                     35964009 |                      9640 |
# +-------------+------------------+------------------------------+---------------------------+
# |           6 |             9640 |                     92929600 |                      9296 |
# +-------------+------------------+------------------------------+---------------------------+
# |           7 |             9296 |                     86415616 |                      4156 |
# +-------------+------------------+------------------------------+---------------------------+
# |           8 |             4156 |                     17272336 |                      2723 |
# +-------------+------------------+------------------------------+---------------------------+
# |           9 |             2723 |                      7414729 |                      4147 |
# +-------------+------------------+------------------------------+---------------------------+
# |          10 |             4147 |                     17197609 |                      1976 |
# +-------------+------------------+------------------------------+---------------------------+
# |          11 |             1976 |                      3904576 |                      9045 |
# +-------------+------------------+------------------------------+---------------------------+
# |          12 |             9045 |                     81812025 |                      8120 |
# +-------------+------------------+------------------------------+---------------------------+
# |          13 |             8120 |                     65934400 |                      9344 |
# +-------------+------------------+------------------------------+---------------------------+
# |          14 |             9344 |                     87310336 |                      3103 |
# +-------------+------------------+------------------------------+---------------------------+
# |          15 |             3103 |                      9628609 |                      6286 |
# +-------------+------------------+------------------------------+---------------------------+
# |          16 |             6286 |                     39513796 |                      5137 |
# +-------------+------------------+------------------------------+---------------------------+
# |          17 |             5137 |                     26388769 |                      3887 |
# +-------------+------------------+------------------------------+---------------------------+
# |          18 |             3887 |                     15108769 |                      1087 |
# +-------------+------------------+------------------------------+---------------------------+
# |          19 |             1087 |                      1181569 |                      1815 |
# +-------------+------------------+------------------------------+---------------------------+
# |          20 |             1815 |                      3294225 |                      2942 |
# +-------------+------------------+------------------------------+---------------------------+
# |          21 |             2942 |                      8655364 |                      6553 |
# +-------------+------------------+------------------------------+---------------------------+
# |          22 |             6553 |                     42941809 |                      9418 |
# +-------------+------------------+------------------------------+---------------------------+
# |          23 |             9418 |                     88698724 |                      6987 |
# +-------------+------------------+------------------------------+---------------------------+
# |          24 |             6987 |                     48818169 |                      8181 |
# +-------------+------------------+------------------------------+---------------------------+
# |          25 |             8181 |                     66928761 |                      9287 |
# +-------------+------------------+------------------------------+---------------------------+
# |          26 |             9287 |                     86248369 |                      2483 |
# +-------------+------------------+------------------------------+---------------------------+
# |          27 |             2483 |                      6165289 |                      1652 |
# +-------------+------------------+------------------------------+---------------------------+
# |          28 |             1652 |                      2729104 |                      7291 |
# +-------------+------------------+------------------------------+---------------------------+
# |          29 |             7291 |                     53158681 |                      1586 |
# +-------------+------------------+------------------------------+---------------------------+
# |          30 |             1586 |                      2515396 |                      5153 |
# +-------------+------------------+------------------------------+---------------------------+
# |          31 |             5153 |                     26553409 |                      5534 |
# +-------------+------------------+------------------------------+---------------------------+
# |          32 |             5534 |                     30625156 |                      6251 |
# +-------------+------------------+------------------------------+---------------------------+
# |          33 |             6251 |                     39075001 |                      0750 |
# +-------------+------------------+------------------------------+---------------------------+
# |          34 |              750 |                       562500 |                      6250 |
# +-------------+------------------+------------------------------+---------------------------+
# |          35 |             6250 |                     39062500 |                      0625 |
# +-------------+------------------+------------------------------+---------------------------+
# |          36 |              625 |                       390625 |                      9062 |
# +-------------+------------------+------------------------------+---------------------------+
# |          37 |             9062 |                     82119844 |                      1198 |
# +-------------+------------------+------------------------------+---------------------------+
# |          38 |             1198 |                      1435204 |                      4352 |
# +-------------+------------------+------------------------------+---------------------------+
# |          39 |             4352 |                     18939904 |                      9399 |
# +-------------+------------------+------------------------------+---------------------------+
# |          40 |             9399 |                     88341201 |                      3412 |
# +-------------+------------------+------------------------------+---------------------------+
# |          41 |             3412 |                     11641744 |                      6417 |
# +-------------+------------------+------------------------------+---------------------------+
# |          42 |             6417 |                     41177889 |                      1778 |
# +-------------+------------------+------------------------------+---------------------------+
# |          43 |             1778 |                      3161284 |                      1612 |
# +-------------+------------------+------------------------------+---------------------------+
# |          44 |             1612 |                      2598544 |                      5985 |
# +-------------+------------------+------------------------------+---------------------------+
# |          45 |             5985 |                     35820225 |                      8202 |
# +-------------+------------------+------------------------------+---------------------------+
# |          46 |             8202 |                     67272804 |                      2728 |
# +-------------+------------------+------------------------------+---------------------------+
# |          47 |             2728 |                      7441984 |                      4419 |
# +-------------+------------------+------------------------------+---------------------------+
# |          48 |             4419 |                     19527561 |                      5275 |
# +-------------+------------------+------------------------------+---------------------------+
# |          49 |             5275 |                     27825625 |                      8256 |
# +-------------+------------------+------------------------------+---------------------------+
# |          50 |             8256 |                     68161536 |                      1615 |
# +-------------+------------------+------------------------------+---------------------------+
# |          51 |             1615 |                      2608225 |                      6082 |
# +-------------+------------------+------------------------------+---------------------------+
# |          52 |             6082 |                     36990724 |                      9907 |
# +-------------+------------------+------------------------------+---------------------------+
# |          53 |             9907 |                     98148649 |                      1486 |
# +-------------+------------------+------------------------------+---------------------------+
# |          54 |             1486 |                      2208196 |                      2081 |
# +-------------+------------------+------------------------------+---------------------------+
# |          55 |             2081 |                      4330561 |                      3305 |
# +-------------+------------------+------------------------------+---------------------------+
# |          56 |             3305 |                     10923025 |                      9230 |
# +-------------+------------------+------------------------------+---------------------------+
# |          57 |             9230 |                     85192900 |                      1929 |
# +-------------+------------------+------------------------------+---------------------------+
# |          58 |             1929 |                      3721041 |                      7210 |
# +-------------+------------------+------------------------------+---------------------------+
# |          59 |             7210 |                     51984100 |                      9841 |
# +-------------+------------------+------------------------------+---------------------------+
# |          60 |             9841 |                     96845281 |                      8452 |
# +-------------+------------------+------------------------------+---------------------------+
# |          61 |             8452 |                     71436304 |                      4363 |
# +-------------+------------------+------------------------------+---------------------------+
# |          62 |             4363 |                     19035769 |                      0357 |
# +-------------+------------------+------------------------------+---------------------------+
# |          63 |              357 |                       127449 |                      2744 |
# +-------------+------------------+------------------------------+---------------------------+
# |          64 |             2744 |                      7529536 |                      5295 |
# +-------------+------------------+------------------------------+---------------------------+
# |          65 |             5295 |                     28037025 |                      0370 |
# +-------------+------------------+------------------------------+---------------------------+
