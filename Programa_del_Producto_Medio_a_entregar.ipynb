# %% [markdown]
# <a href="https://colab.research.google.com/github/alexloaeza12/Simulaci-n-I/blob/main/Programa_del_Producto_Medio_a_entregar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Programa del Producto Medio**
#
# ---
#
#
#
# ---

# %% [markdown]
# Nuestro programa solicitará al ususario dos números iniciales de 3 dígitos, dichos número se multiplicarán entre si y del resultado obtenido se obtendrán los 3 dígitos de en medio.
#
# El ciclo se vuelve a repetirá de una manera curiosa. Nuestro segundo factor pasará a ser el ahora primer factor y nuestro resultado obtenido pasará a ser el segundo factor.
#
# ---
#
#
#
# ---

# %% [markdown]
# El programa pedirá al ususario que ingrese dos número de 3 dígitos, si el usuario ingresa más o menos dígitos, el programa volverá a solicitar que ingrese adecuadamente ambos números con 3 dígitos

# %%
#Importamos "tabulate" para hacer nuestra tabla de una manera más presentable
from tabulate import tabulate

print("********************************")
print("* Programa del Producto Medio *")
print("********************************\n")

    #Solicitamos al usuario el primer número de 3 dígitos
while True:
    num_alt = input("Ingresa un número de 3 dígitos como primer factor: ")
    if num_alt.isdigit() and len(num_alt) == 3:
        num_alt = int(num_alt)
        break
    else:
        print("Por favor, ingresa un número válido de 3 dígitos.")

    #Solicitamos al usuario el segundo número de 3 dígitos
while True:
    num_alt2 = input("Ingresa un número de 3 dígitos como segundo factor: ")
    if num_alt2.isdigit() and len(num_alt2) == 3:
        num_alt2 = int(num_alt2)
        break
    else:
        print("Por favor, ingresa un número válido de 3 dígitos.")
# Out:
# ********************************
# * Programa del Producto Medio *
# ********************************
#
# Ingresa un número de 3 dígitos como primer factor: 234
# Ingresa un número de 3 dígitos como segundo factor: 567

# %% [markdown]
# Ahora el programá pedirá las iteraciones que deseemos realizar.

# %%
    #Solicitamos al usuario la cantidad de iteraciones
num_iteraciones = int(input("Ingresa la cantidad de iteraciones que deseas realizar: "))
# Out:
# Ingresa la cantidad de iteraciones que deseas realizar: 150

# %% [markdown]
# Todo se almacenará en un lista, que estará reflejado en nuestra tabla.

# %%
#Almacenamos los resultados en una lista
resultados = []

    #Construimos los datos para la tabla
for i in range(num_iteraciones):
    #Multiplicamos los dos números
    num_alt3 = num_alt * num_alt2

    #Convertimos el resultado a cadena y obtenemos la longitud
    result_str = str(num_alt3)
    result_length = len(result_str)

    #Verificamos si la longitud es par, y si es así, añadimos un '0' al principio
    #result_length += 1. Se ha agregado un '0' al principio, por lo que la longitud debe incrementarse.
    if result_length % 2 == 0:
        result_str = '0' + result_str
        result_length += 1

    #Calculamos la posición inicial y final para los 3 dígitos de en medio
    inicio = (result_length - 3) // 2
    final = inicio + 3

    #Extraemos los 3 dígitos de en medio
    medio = result_str[inicio:final]

    #Almacenar los resultados en la lista
    resultados.append((i + 1, num_alt, num_alt2, num_alt3, medio))

    #Establecemos el nuevo valor de num_alt y num_alt2 para la siguiente iteración
    num_alt = num_alt2
    num_alt2 = int(medio)

    #Imprimimos la tabla
headers = ["Iteración", "Primer Factor", "Segundo Factor", "Producto", "Dígitos de en medio"]
print(tabulate(resultados, headers=headers, tablefmt="grid"))
# Out:
# +-------------+-----------------+------------------+------------+-----------------------+
# |   Iteración |   Primer Factor |   Segundo Factor |   Producto |   Dígitos de en medio |
# +=============+=================+==================+============+=======================+
# |           1 |             563 |              873 |     491499 |                   914 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |           2 |             873 |              914 |     797922 |                   979 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |           3 |             914 |              979 |     894806 |                   948 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |           4 |             979 |              948 |     928092 |                   280 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |           5 |             948 |              280 |     265440 |                   654 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |           6 |             280 |              654 |     183120 |                   831 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |           7 |             654 |              831 |     543474 |                   434 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |           8 |             831 |              434 |     360654 |                   606 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |           9 |             434 |              606 |     263004 |                   630 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          10 |             606 |              630 |     381780 |                   817 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          11 |             630 |              817 |     514710 |                   147 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          12 |             817 |              147 |     120099 |                   200 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          13 |             147 |              200 |      29400 |                   940 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          14 |             200 |              940 |     188000 |                   880 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          15 |             940 |              880 |     827200 |                   272 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          16 |             880 |              272 |     239360 |                   393 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          17 |             272 |              393 |     106896 |                   068 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          18 |             393 |               68 |      26724 |                   672 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          19 |              68 |              672 |      45696 |                   569 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          20 |             672 |              569 |     382368 |                   823 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          21 |             569 |              823 |     468287 |                   682 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          22 |             823 |              682 |     561286 |                   612 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          23 |             682 |              612 |     417384 |                   173 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          24 |             612 |              173 |     105876 |                   058 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          25 |             173 |               58 |      10034 |                   003 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          26 |              58 |                3 |        174 |                   174 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          27 |               3 |              174 |        522 |                   522 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          28 |             174 |              522 |      90828 |                   082 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          29 |             522 |               82 |      42804 |                   280 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          30 |              82 |              280 |      22960 |                   296 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          31 |             280 |              296 |      82880 |                   288 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          32 |             296 |              288 |      85248 |                   524 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          33 |             288 |              524 |     150912 |                   509 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          34 |             524 |              509 |     266716 |                   667 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          35 |             509 |              667 |     339503 |                   395 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          36 |             667 |              395 |     263465 |                   634 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          37 |             395 |              634 |     250430 |                   504 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          38 |             634 |              504 |     319536 |                   195 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          39 |             504 |              195 |      98280 |                   828 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          40 |             195 |              828 |     161460 |                   614 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          41 |             828 |              614 |     508392 |                   083 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          42 |             614 |               83 |      50962 |                   096 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          43 |              83 |               96 |       7968 |                   796 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          44 |              96 |              796 |      76416 |                   641 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          45 |             796 |              641 |     510236 |                   102 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          46 |             641 |              102 |      65382 |                   538 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          47 |             102 |              538 |      54876 |                   487 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          48 |             538 |              487 |     262006 |                   620 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          49 |             487 |              620 |     301940 |                   019 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          50 |             620 |               19 |      11780 |                   178 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          51 |              19 |              178 |       3382 |                   338 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          52 |             178 |              338 |      60164 |                   016 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          53 |             338 |               16 |       5408 |                   540 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          54 |              16 |              540 |       8640 |                   864 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          55 |             540 |              864 |     466560 |                   665 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          56 |             864 |              665 |     574560 |                   745 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          57 |             665 |              745 |     495425 |                   954 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          58 |             745 |              954 |     710730 |                   107 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          59 |             954 |              107 |     102078 |                   020 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          60 |             107 |               20 |       2140 |                   214 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          61 |              20 |              214 |       4280 |                   428 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          62 |             214 |              428 |      91592 |                   159 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          63 |             428 |              159 |      68052 |                   805 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          64 |             159 |              805 |     127995 |                   279 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          65 |             805 |              279 |     224595 |                   245 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          66 |             279 |              245 |      68355 |                   835 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          67 |             245 |              835 |     204575 |                   045 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          68 |             835 |               45 |      37575 |                   757 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          69 |              45 |              757 |      34065 |                   406 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          70 |             757 |              406 |     307342 |                   073 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          71 |             406 |               73 |      29638 |                   963 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          72 |              73 |              963 |      70299 |                   029 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          73 |             963 |               29 |      27927 |                   792 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          74 |              29 |              792 |      22968 |                   296 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          75 |             792 |              296 |     234432 |                   344 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          76 |             296 |              344 |     101824 |                   018 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          77 |             344 |               18 |       6192 |                   619 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          78 |              18 |              619 |      11142 |                   114 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          79 |             619 |              114 |      70566 |                   056 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          80 |             114 |               56 |       6384 |                   638 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          81 |              56 |              638 |      35728 |                   572 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          82 |             638 |              572 |     364936 |                   649 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          83 |             572 |              649 |     371228 |                   712 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          84 |             649 |              712 |     462088 |                   620 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          85 |             712 |              620 |     441440 |                   414 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          86 |             620 |              414 |     256680 |                   566 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          87 |             414 |              566 |     234324 |                   343 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          88 |             566 |              343 |     194138 |                   941 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          89 |             343 |              941 |     322763 |                   227 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          90 |             941 |              227 |     213607 |                   136 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          91 |             227 |              136 |      30872 |                   087 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          92 |             136 |               87 |      11832 |                   183 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          93 |              87 |              183 |      15921 |                   592 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          94 |             183 |              592 |     108336 |                   083 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          95 |             592 |               83 |      49136 |                   913 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          96 |              83 |              913 |      75779 |                   577 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          97 |             913 |              577 |     526801 |                   268 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          98 |             577 |              268 |     154636 |                   546 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |          99 |             268 |              546 |     146328 |                   463 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         100 |             546 |              463 |     252798 |                   527 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         101 |             463 |              527 |     244001 |                   440 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         102 |             527 |              440 |     231880 |                   318 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         103 |             440 |              318 |     139920 |                   399 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         104 |             318 |              399 |     126882 |                   268 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         105 |             399 |              268 |     106932 |                   069 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         106 |             268 |               69 |      18492 |                   849 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         107 |              69 |              849 |      58581 |                   858 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         108 |             849 |              858 |     728442 |                   284 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         109 |             858 |              284 |     243672 |                   436 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         110 |             284 |              436 |     123824 |                   238 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         111 |             436 |              238 |     103768 |                   037 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         112 |             238 |               37 |       8806 |                   880 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         113 |              37 |              880 |      32560 |                   256 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         114 |             880 |              256 |     225280 |                   252 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         115 |             256 |              252 |      64512 |                   451 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         116 |             252 |              451 |     113652 |                   136 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         117 |             451 |              136 |      61336 |                   133 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         118 |             136 |              133 |      18088 |                   808 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         119 |             133 |              808 |     107464 |                   074 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         120 |             808 |               74 |      59792 |                   979 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         121 |              74 |              979 |      72446 |                   244 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         122 |             979 |              244 |     238876 |                   388 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         123 |             244 |              388 |      94672 |                   467 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         124 |             388 |              467 |     181196 |                   811 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         125 |             467 |              811 |     378737 |                   787 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         126 |             811 |              787 |     638257 |                   382 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         127 |             787 |              382 |     300634 |                   006 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         128 |             382 |                6 |       2292 |                   229 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         129 |               6 |              229 |       1374 |                   137 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         130 |             229 |              137 |      31373 |                   137 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         131 |             137 |              137 |      18769 |                   876 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         132 |             137 |              876 |     120012 |                   200 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         133 |             876 |              200 |     175200 |                   752 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         134 |             200 |              752 |     150400 |                   504 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         135 |             752 |              504 |     379008 |                   790 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         136 |             504 |              790 |     398160 |                   981 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         137 |             790 |              981 |     774990 |                   749 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         138 |             981 |              749 |     734769 |                   347 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         139 |             749 |              347 |     259903 |                   599 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         140 |             347 |              599 |     207853 |                   078 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         141 |             599 |               78 |      46722 |                   672 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         142 |              78 |              672 |      52416 |                   241 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         143 |             672 |              241 |     161952 |                   619 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         144 |             241 |              619 |     149179 |                   491 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         145 |             619 |              491 |     303929 |                   039 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         146 |             491 |               39 |      19149 |                   914 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         147 |              39 |              914 |      35646 |                   564 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         148 |             914 |              564 |     515496 |                   154 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         149 |             564 |              154 |      86856 |                   685 |
# +-------------+-----------------+------------------+------------+-----------------------+
# |         150 |             154 |              685 |     105490 |                   054 |
# +-------------+-----------------+------------------+------------+-----------------------+
