# %% [markdown]
# <a href="https://colab.research.google.com/github/alexloaeza12/Simulaci-n-I/blob/main/M%C3%A9todo_Aceptaci%C3%B3n_rechazo_entregar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Método de la transformada inversa
#
# El ejemplo incluiye:
#
# - Gráfica de la función de densidad de probabilidad (fdp).
# - Gráfica de la función acumulativa.
# - Histograma de la muestra generada.
# - Notas y aclaraciones documentadas.
#
#
# ---
#
#
#
# ---

# %% [markdown]
# La función de densidad de probabilidad es  f(x) = e^{-|2x|}

# %% [markdown]
# Importamos la librarías necesarias

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from scipy.integrate import quad

# %% [markdown]
# Verificación de que la fdp es una función válida
# - Verificamos que la integral de 0 a 1, sea 1.

# %%
# Definimos la función de densidad de probabilidad (fdp)
def fdp(x):
    return np.exp(-np.abs(2 * x))

# Verificamos que la integral de la fdp de -∞ a ∞ sea 1
integral, _ = quad(fdp, -np.inf, np.inf)
print(f'Integral de la fdp de -∞ a ∞: {integral}')  # Debe ser 1
# Out:
# Integral de la fdp de -∞ a ∞: 0.9999999999999999

# %% [markdown]
# Procedemos con el método
# - Gráficamos de la función de densidad de probabilidad (fdp).

# %%
# Definimos la función de comparación g(x)
def g(x):
    return 0.5 * np.exp(-np.abs(x))

# Constante de normalización
c = 2

lista = []
while len(lista) < 10000:
    # Generamos un valor candidato de g(x)
    y = random.uniform(-10, 10)
    u = random.random()
    if u <= fdp(y) / (c * g(y)):
        lista.append(y)

x_vals = np.linspace(-3, 3, 1000)
fdp_vals = fdp(x_vals)

# Graficamos la fdp
plt.figure(figsize=(8, 6))
plt.plot(x_vals, fdp_vals, label='FDP')
plt.title('Función de Densidad de Probabilidad (FDP)')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Graficamos el histograma de la muestra generada

# %%
plt.figure(figsize=(8, 6))
plt.hist(lista, bins=50, density=True, alpha=0.6, color='g', label='Histograma de la muestra')
plt.title('Histograma de la muestra generada vs FDP teórica')
plt.xlabel('x')
plt.ylabel('Densidad')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Graficamos el histograma de la muestra generada

# %%
def cdf(muestra):
    n = len(muestra)
    x = np.sort(muestra)
    y = np.arange(1, n + 1) / n
    return x, y

X, Y = cdf(lista)

# Graficamos la función acumulativa
plt.figure(figsize=(8, 6))
plt.step(X, Y, where='post', label='CDF')
plt.title('Función de Distribución Acumulativa')
plt.xlabel('x')
plt.ylabel('F(x)')
plt.legend()
plt.grid(True)
plt.show()
